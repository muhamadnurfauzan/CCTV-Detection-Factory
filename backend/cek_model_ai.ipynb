# %% [markdown]
# ## Impor Yolo untuk mengetahui class dari model yang digunakan
# Impor YOLO dari ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# # 1. Cek class pada model "best.pt"

# %%
model = YOLO("model/best.pt")
print(model.names)  # kelas yang bisa dideteksi
# Out:
# {0: 'With Helmet', 1: 'Without Helmet'}

# %% [markdown]
# # 2. Cek class pada model "helm detection.pt"

# %%
model_2 = YOLO("model/helm detection.pt")
print(model_2.names)
# Out:
# {0: 'boots', 1: 'gloves', 2: 'goggles', 3: 'helmet', 4: 'no-boots', 5: 'no-gloves', 6: 'no-goggles', 7: 'no-helmet', 8: 'no-vest', 9: 'vest'}

# %% [markdown]
# # Cek informasi OpenCV yang digunakan
# Pastikan FFMPEG yes

# %%
import cv2
print(cv2.__version__)           # Menampilkan versi OpenCV
print(cv2.getBuildInformation()) # Menampilkan informasi lengkap build
# Out:
# 4.11.0
#
# General configuration for OpenCV 4.11.0 =====================================
#   Version control:               unknown
#
#   Extra modules:
#     Location (extra):            /Users/runner/miniforge3/conda-bld/libopencv_1750205119127/work/opencv_contrib/modules
#     Version control (extra):     unknown
#
#   Platform:
#     Timestamp:                   2025-06-18T00:11:33Z
#     Host:                        Darwin 22.6.0 x86_64
#     CMake:                       4.0.3
#     CMake generator:             Ninja
#     CMake build tool:            /Users/runner/miniforge3/conda-bld/libopencv_1750205119127/_build_env/bin/ninja
#     Configuration:               Release
#     Algorithm Hint:              ALGO_HINT_ACCURATE
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3 SSSE3
#       requested:                 DETECT
#     Dispatched code generation:  SSE4_1 SSE4_2 AVX FP16 AVX2 AVX512_SKX
#       SSE4_1 (16 files):         + SSE4_1
# ...

# %% [markdown]
# # Cek apakah device yang digunakan memiliki GPU
# True = memiliki
# Fasle = tidak memiliki

# %%
import torch
torch.cuda.is_available()
# Out:
# False
